# %%
import sys
from pathlib import Path

project_root = Path.cwd().parents[0]
pkg_parent    = project_root / "core-periphery-detection-master"
sys.path.insert(0, str(pkg_parent))             

import cpnet_new
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
## social networks
# https://networkrepository.com/fb-pages-food.php
# https://networkrepository.com/fb-pages-tvshow.php

## biological networks
# https://networkrepository.com/bio-celegans.php
# https://networkrepository.com/bio-CE-GT.php 

## techonological
# https://networkrepository.com/inf-USAir97.php explanation https://nps.edu/web/faculty-rgera/networkprofilesummaryresources?utm_source=chatgpt.com
# https://networks.skewed.de/net/webkb?utm_source=chatgpt.com webkb_wisconsin_link1 and webkb_wisconsin_cocite

#!/usr/bin/env python3
"""
Load six empirical networks as undirected, unweighted simple graphs (no loops) with NetworkX.

Sources (relative to ../empirical_networks):
- bio-CE-GN/bio-CE-GN.edges              (space-separated, 3 columns -> ignore 3rd)
- bio-celegans/bio-celegans.mtx          (MatrixMarket, skip first 2 lines)
- fb-pages-food/fb-pages-food.edges      (CSV, two columns)
- fb-pages-tvshow/fb-pages-tvshow.edges  (CSV, two columns)
- tech-routers-rf/tech-routers-rf.
- web-edu/web-edu.mtx                    (MatrixMarket, skip first 2 lines)

Each NetworkX Graph has its .name set to the *filename* used as the data source (e.g., "bio-CE-GN.edges").
All graphs are also returned in a dict keyed by that filename.
"""
from pathlib import Path
from typing import Dict
import networkx as nx
from scipy.io import mmread

G_fb_food = nx.read_edgelist('empirical_networks/fb-pages-food/fb-pages-food.edges', delimiter=',')
G_fb_food.remove_edges_from(nx.selfloop_edges(G_fb_food))
matrix_bio_celegans = mmread('empirical_networks/bio-celegans/bio-celegans.mtx')
G_bio_celegans = nx.from_scipy_sparse_array(matrix_bio_celegans)
G_bio_CE_GT = nx.read_edgelist('empirical_networks/bio-CE-GT/bio-CE-GT.edges', data=False)
matrix_rt_retweet = mmread('empirical_networks/rt-retweet/rt-retweet.mtx')
G_rt_retweet = nx.from_scipy_sparse_array(matrix_rt_retweet)
matrix_USAir = mmread('empirical_networks/inf-USAir97/inf-USAir97.mtx')
G_USAir = nx.from_scipy_sparse_array(matrix_USAir)
G_web_wisconsin = nx.read_edgelist('empirical_networks/webkb_wisconsin_link1.csv/edges.csv', delimiter=',', data=False)
G_web_wisconsin.remove_edges_from(nx.selfloop_edges(G_web_wisconsin))


graphs = [G_fb_food,G_bio_celegans,G_bio_CE_GT,G_rt_retweet,G_USAir,G_web_wisconsin]

for fname, G in graphs.items():
    print(f"{fname}: nodes={G.number_of_nodes()}, edges={G.number_of_edges()}, name={G.name}")

## test 
for fname, G in graphs.items():
    if fname=="bio-CE-GT.edges":
        alg = cpnet_new.BE()

        alg.detect(G) 

        x = alg.get_coreness() 

        c = alg.get_pair_id() 
        
        sig_c, sig_x, significant, p_values = cpnet_new.qstest(
            c, x, G, alg, significance_level=0.01, num_of_thread=16
        )
# Out:
# bio-CE-GT.edges: nodes=924, edges=3239, name=bio-CE-GT.edges
# bio-celegans.mtx: nodes=453, edges=2025, name=bio-celegans.mtx
# fb-pages-food.edges: nodes=620, edges=2091, name=fb-pages-food.edges
# inf-USAir97.mtx: nodes=332, edges=2126, name=inf-USAir97.mtx
# rt-retweet.mtx: nodes=96, edges=117, name=rt-retweet.mtx
# edges.csv: nodes=297, edges=1130, name=edges.csv
#   8%|▊         | 8/100 [06:12<1:11:20, 46.53s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 210
#     208 c = alg.get_pair_id() # get the group membership of nodes 1 is maximum core, 0 is most preriphery
#     209 ## fracitonal values are only possible in the continous model
# --> 210 sig_c, sig_x, significant, p_values = cpnet_new.qstest(
#     211     c, x, G, alg, significance_level=0.01, num_of_thread=16
#     212 )
#
# File ~/complex_networks_mini_project_numeric_sim/core-periphery-detection-master/cpnet_new/qstest.py:109, in qstest(pair_id, coreness, G, cpa, significance_level, null_model, sfunc, num_of_rand_net, q_tilde, s_tilde, **params)
#     107 results = []
#     108 for _ in tqdm(range(num_of_rand_net)):
# --> 109     results+=[sampling(G, cpa, sfunc, null_model)]
#     110 if isinstance(results[0]["q"], list):
#     111     q_tilde = np.array(sum([res["q"] for res in results], []))
#
# File ~/complex_networks_mini_project_numeric_sim/core-periphery-detection-master/cpnet_new/qstest.py:36, in sampling(G, cpa, sfunc, null_model)
#      34 Gr = null_model(G)
#      35 Ar = sparse.csr_matrix(nx.adjacency_matrix(Gr))
# ---> 36 cpa.detect(Ar)
#      37 q_rand = cpa.qs_
#      38 s_rand = sfunc(Ar, cpa.c_, cpa.x_)
#
# File ~/complex_networks_mini_project_numeric_sim/core-periphery-detection-master/cpnet_new/BE.py:60, in BE.detect(self, G)
#      57     Q, qs = _score_(A_indptr, A_indices, A_data, cids, x, num_nodes)
#      58     return {"cids": cids, "x": x, "q": Q}
# ---> 60 res = Parallel(n_jobs=self.n_jobs)(
#      61     delayed(_detect)(A.indptr, A.indices, A.data, A.shape[0])
#      62     for i in range(self.num_runs)
#      63 )
#      64 res = max(res, key=lambda x: x["q"])
#      65 cids, x, Q = res["cids"], res["x"], res["q"]
#
# File ~/complex_networks_mini_project_numeric_sim/complex_networks_mini_proj/lib/python3.11/site-packages/joblib/parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File ~/complex_networks_mini_project_numeric_sim/complex_networks_mini_proj/lib/python3.11/site-packages/joblib/parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File ~/complex_networks_mini_project_numeric_sim/core-periphery-detection-master/cpnet_new/BE.py:54, in BE.detect.<locals>._detect(A_indptr, A_indices, A_data, num_nodes)
#      53 def _detect(A_indptr, A_indices, A_data, num_nodes):
# ---> 54     x = _kernighan_lin_(A_indptr, A_indices, A_data, num_nodes)
#      55     x = x.astype(int)
#      56     cids = np.zeros(num_nodes).astype(int)
#
# File ~/complex_networks_mini_project_numeric_sim/complex_networks_mini_proj/lib/python3.11/site-packages/numba/core/serialize.py:30, in _numba_unpickle(address, bytedata, hashed)
#      26 # Keep unpickled object via `numba_unpickle` alive.
#      27 _unpickled_memo = {}
# ---> 30 def _numba_unpickle(address, bytedata, hashed):
#      31     """Used by `numba_unpickle` from _helperlib.c
#      32
#      33     Parameters
#    (...)     42         unpickled object
#      43     """
#      44     key = (address, hashed)
#
# KeyboardInterrupt:
